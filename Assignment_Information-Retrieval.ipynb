# %% [markdown]
# # Assignment 2: IR

# %% [markdown]
# ## Preparations
# * Put all your imports, and path constants in the next cells
# * Make sure all your path constants are **relative to** ***DATA_DIR*** and **NOT hard-coded** in your code.

# %%
# imports
from whoosh import index, writing, qparser, scoring
from whoosh.fields import Schema, TEXT, KEYWORD, ID, STORED
from whoosh.analysis import *
from whoosh.qparser import QueryParser, MultifieldParser
import os.path
import time
from pathlib import Path
import tempfile
import subprocess

# %%
DATA_DIR = "government"

DOCUMENTS_DIR = os.path.join(DATA_DIR, "documents")
TOPIC_FILE = os.path.join(DATA_DIR, "gov.topics")
QRELS_FILE = os.path.join(DATA_DIR, "gov.qrels")

TREC_EVAL = os.path.join("trec_eval", "trec_eval.exe")

# %% [markdown]
# ## Question 1
# Provide your text answers in the following two markdown cells

# %% [markdown]
# ### Q1 (a): Provide answer to Q1 (a) here [markdown cell]
#
# Chosen measure:
# - **gm_map(Geometric Mean of Average Precision)  - overall queries**
# - **map(Mean of Average Precision) - each query**
#
# ***Note: gm_map only available for overall measurement, map will be used for each query***

# %% [markdown]
# ### Q1 (b): Provide answer to Q1 (b) here [markdown cell]
#
# Under the assumptions that government websites' users are interested in finding many relevant documents for each query, and average previsions in real world is normally skewed, therefore, (geometric)mean of average precision are used since both consider # of revelent documents and # of retrieved revelent documents.
#
# Source: http://www.cs.sfu.ca/CourseCentral/456/jpei/web%20slides/L19%20-%20Evaluation.pdf

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### Q2 (a): Write your code below
# Save your index (after indexing all the documents) in the provided variable INDEX_Q2, your query parser in the provided variable QP_Q2, and your searcher in the provided variable SEARCHER_Q2.

# %% [markdown]
#    #### Creating the index

# %%
def createIndex(schema):
    # Generate a temporary directory for the index
    indexDir = tempfile.mkdtemp()

    # create and return the index
    return index.create_in(indexDir, schema)

# first, define a Schema for the index
mySchema = Schema(file_path = ID(stored=True),
                  file_content = TEXT(analyzer = RegexTokenizer()))

# now, create the index at the path INDEX_DIR based on the new schema
INDEX_Q2 = createIndex(mySchema)

# %% [markdown]
# #### Indexing the documents

# %%
def addFilesToIndex(indexObj, fileList):
    start = time.time()
    # open writer
    writer = writing.BufferedWriter(indexObj, period=None, limit=1000)

    try:
        # write each file to index
        for docNum, filePath in enumerate(fileList):
            with open(filePath, "r", encoding="utf-8") as f:
                fileContent = f.read()
                writer.add_document(file_path = filePath,
                                    file_content = fileContent)

                # print status every 1000 documents
                if (int(docNum+1) % 1000 == 0):
                    print("already indexed:", docNum+1)
        end = time.time()
        print("done indexing, time spent: " + str("%.2f" % (end - start)) + "s.")

    finally:
        # close the index
        writer.close()
    
    
        
# Build a list of files to index check if file not a directory
filesToIndex = [str(filePath) for filePath in Path(DOCUMENTS_DIR).glob("**/*") if filePath.is_file()]

# %%
# count files to index
print("number of files:", len(filesToIndex))
# Out:
# number of files: 4078

# %%
addFilesToIndex(INDEX_Q2, filesToIndex)
# Out:
# already indexed: 1000
# already indexed: 2000
# already indexed: 3000
# already indexed: 4000
# done indexing, time spent: 53.19s.

# %%
INDEX_Q2
# Out:
# FileIndex(FileStorage('C:\\Users\\austi\\AppData\\Local\\Temp\\tmpliwe6hft'), 'MAIN')

# %% [markdown]
# #### Querying

# %%
# define a query parser for the field "file_content" in the 
# two objects
QP_Q2 = QueryParser("file_content", schema=INDEX_Q2.schema)
SEARCHER_Q2 = INDEX_Q2.searcher()

# %% [markdown]
# #### Evaluation using TREC_EVAL

# %%
# print the topic file
with open(TOPIC_FILE, "r") as f:
    print(f.read())
# Out:
# 1 mining gold silver coal
# 2 juvenile delinquency
# 4 wireless communications
# 6 physical therapists
# 7 cotton industry
# 9 genealogy searches
# 10 Physical Fitness
# 14 Agricultural biotechnology
# 16 Emergency and disaster preparedness assistance
# 18 Shipwrecks
# 19 Cybercrime, internet fraud, and cyber fraud
# 22 Veteran's Benefits
# 24 Air Bag Safety
# 26 Nuclear power plants
# 28 Early Childhood Education

# %%
def trecEval(topicFile, qrelsFile, queryParser, searcher):
    # Load topic file - a list of topics(search phrases) used for evalutation
    with open(topicFile, "r") as tf:
        topics = tf.read().splitlines()

    # create an output file to which we'll write our results
    tempOutputFile = tempfile.mkstemp()[1]
    with open(tempOutputFile, "w") as outputTRECFile:
        # for each evaluated topic:
        # build a query and record the results in the file in TREC_EVAL format
        for topic in topics:
            topic_id, topic_phrase = tuple(topic.split(" ", 1))
            topicQuery = queryParser.parse(topic_phrase)
            topicResults = searcher.search(topicQuery, limit=None)
            for (docnum, result) in enumerate(topicResults):
                score = topicResults.score(docnum)
                outputTRECFile.write("%s Q0 %s %d %lf test\n" % (topic_id, os.path.basename(result["file_path"]), docnum, score))
    
    result = subprocess.run([TREC_EVAL, '-q', qrelsFile, tempOutputFile], stdout=subprocess.PIPE)
    print(result.stdout.decode())

# %%
trecEval(TOPIC_FILE, QRELS_FILE, QP_Q2, SEARCHER_Q2)
# Out:
# num_ret               	1	1
# num_rel               	1	5
# num_rel_ret           	1	0
# map                   	1	0.0000
# Rprec                 	1	0.0000
# bpref                 	1	0.0000
# recip_rank            	1	0.0000
# iprec_at_recall_0.00  	1	0.0000
# iprec_at_recall_0.10  	1	0.0000
# iprec_at_recall_0.20  	1	0.0000
# iprec_at_recall_0.30  	1	0.0000
# iprec_at_recall_0.40  	1	0.0000
# iprec_at_recall_0.50  	1	0.0000
# iprec_at_recall_0.60  	1	0.0000
# iprec_at_recall_0.70  	1	0.0000
# iprec_at_recall_0.80  	1	0.0000
# iprec_at_recall_0.90  	1	0.0000
# iprec_at_recall_1.00  	1	0.0000
# P_5                   	1	0.0000
# P_10                  	1	0.0000
# P_15                  	1	0.0000
# P_20                  	1	0.0000
# P_30                  	1	0.0000
# P_100                 	1	0.0000
# P_200                 	1	0.0000
# P_500                 	1	0.0000
# P_1000                	1	0.0000
# num_ret               	10	16
# num_rel               	10	1
# num_rel_ret           	10	1
# map                   	10	0.1667
# Rprec                 	10	0.0000
# bpref                 	10	0.0000
# recip_rank            	10	0.1667
# iprec_at_recall_0.00  	10	0.1667
# iprec_at_recall_0.10  	10	0.1667
# iprec_at_recall_0.20  	10	0.1667
# iprec_at_recall_0.30  	10	0.1667
# iprec_at_recall_0.40  	10	0.1667
# iprec_at_recall_0.50  	10	0.1667
# iprec_at_recall_0.60  	10	0.1667
# iprec_at_recall_0.70  	10	0.1667
# iprec_at_recall_0.80  	10	0.1667
# iprec_at_recall_0.90  	10	0.1667
# iprec_at_recall_1.00  	10	0.1667
# P_5                   	10	0.0000
# P_10                  	10	0.1000
# P_15                  	10	0.0667
# P_20                  	10	0.0500
# P_30                  	10	0.0333
# P_100                 	10	0.0100
# P_200                 	10	0.0050
# P_500                 	10	0.0020
# P_1000                	10	0.0010
# num_ret               	14	7
# num_rel               	14	1
# num_rel_ret           	14	1
# map                   	14	0.2500
# Rprec                 	14	0.0000
# bpref                 	14	0.0000
# recip_rank            	14	0.2500
# iprec_at_recall_0.00  	14	0.2500
# iprec_at_recall_0.10  	14	0.2500
# iprec_at_recall_0.20  	14	0.2500
# iprec_at_recall_0.30  	14	0.2500
# iprec_at_recall_0.40  	14	0.2500
# iprec_at_recall_0.50  	14	0.2500
# iprec_at_recall_0.60  	14	0.2500
# iprec_at_recall_0.70  	14	0.2500
# iprec_at_recall_0.80  	14	0.2500
# iprec_at_recall_0.90  	14	0.2500
# iprec_at_recall_1.00  	14	0.2500
# P_5                   	14	0.2000
# P_10                  	14	0.1000
# P_15                  	14	0.0667
# P_20                  	14	0.0500
# P_30                  	14	0.0333
# P_100                 	14	0.0100
# P_200                 	14	0.0050
# P_500                 	14	0.0020
# P_1000                	14	0.0010
# num_ret               	16	7
# num_rel               	16	7
# num_rel_ret           	16	0
# map                   	16	0.0000
# Rprec                 	16	0.0000
# bpref                 	16	0.0000
# recip_rank            	16	0.0000
# iprec_at_recall_0.00  	16	0.0000
# iprec_at_recall_0.10  	16	0.0000
# iprec_at_recall_0.20  	16	0.0000
# iprec_at_recall_0.30  	16	0.0000
# iprec_at_recall_0.40  	16	0.0000
# iprec_at_recall_0.50  	16	0.0000
# iprec_at_recall_0.60  	16	0.0000
# iprec_at_recall_0.70  	16	0.0000
# iprec_at_recall_0.80  	16	0.0000
# iprec_at_recall_0.90  	16	0.0000
# iprec_at_recall_1.00  	16	0.0000
# P_5                   	16	0.0000
# P_10                  	16	0.0000
# P_15                  	16	0.0000
# P_20                  	16	0.0000
# P_30                  	16	0.0000
# P_100                 	16	0.0000
# P_200                 	16	0.0000
# P_500                 	16	0.0000
# P_1000                	16	0.0000
# num_ret               	18	17
# num_rel               	18	1
# num_rel_ret           	18	1
# map                   	18	1.0000
# Rprec                 	18	1.0000
# bpref                 	18	1.0000
# recip_rank            	18	1.0000
# iprec_at_recall_0.00  	18	1.0000
# iprec_at_recall_0.10  	18	1.0000
# iprec_at_recall_0.20  	18	1.0000
# iprec_at_recall_0.30  	18	1.0000
# iprec_at_recall_0.40  	18	1.0000
# iprec_at_recall_0.50  	18	1.0000
# iprec_at_recall_0.60  	18	1.0000
# iprec_at_recall_0.70  	18	1.0000
# iprec_at_recall_0.80  	18	1.0000
# iprec_at_recall_0.90  	18	1.0000
# iprec_at_recall_1.00  	18	1.0000
# P_5                   	18	0.2000
# P_10                  	18	0.1000
# P_15                  	18	0.0667
# P_20                  	18	0.0500
# P_30                  	18	0.0333
# P_100                 	18	0.0100
# P_200                 	18	0.0050
# P_500                 	18	0.0020
# P_1000                	18	0.0010
# num_ret               	2	6
# num_rel               	2	2
# num_rel_ret           	2	0
# map                   	2	0.0000
# Rprec                 	2	0.0000
# bpref                 	2	0.0000
# recip_rank            	2	0.0000
# iprec_at_recall_0.00  	2	0.0000
# iprec_at_recall_0.10  	2	0.0000
# iprec_at_recall_0.20  	2	0.0000
# iprec_at_recall_0.30  	2	0.0000
# iprec_at_recall_0.40  	2	0.0000
# iprec_at_recall_0.50  	2	0.0000
# iprec_at_recall_0.60  	2	0.0000
# iprec_at_recall_0.70  	2	0.0000
# iprec_at_recall_0.80  	2	0.0000
# iprec_at_recall_0.90  	2	0.0000
# iprec_at_recall_1.00  	2	0.0000
# P_5                   	2	0.0000
# P_10                  	2	0.0000
# P_15                  	2	0.0000
# P_20                  	2	0.0000
# P_30                  	2	0.0000
# P_100                 	2	0.0000
# P_200                 	2	0.0000
# P_500                 	2	0.0000
# P_1000                	2	0.0000
# num_ret               	22	17
# num_rel               	22	1
# num_rel_ret           	22	1
# map                   	22	0.2000
# Rprec                 	22	0.0000
# bpref                 	22	0.0000
# recip_rank            	22	0.2000
# iprec_at_recall_0.00  	22	0.2000
# iprec_at_recall_0.10  	22	0.2000
# iprec_at_recall_0.20  	22	0.2000
# iprec_at_recall_0.30  	22	0.2000
# iprec_at_recall_0.40  	22	0.2000
# iprec_at_recall_0.50  	22	0.2000
# iprec_at_recall_0.60  	22	0.2000
# iprec_at_recall_0.70  	22	0.2000
# iprec_at_recall_0.80  	22	0.2000
# iprec_at_recall_0.90  	22	0.2000
# iprec_at_recall_1.00  	22	0.2000
# P_5                   	22	0.2000
# P_10                  	22	0.1000
# P_15                  	22	0.0667
# P_20                  	22	0.0500
# P_30                  	22	0.0333
# P_100                 	22	0.0100
# P_200                 	22	0.0050
# P_500                 	22	0.0020
# P_1000                	22	0.0010
# num_ret               	24	7
# num_rel               	24	1
# num_rel_ret           	24	1
# map                   	24	1.0000
# Rprec                 	24	1.0000
# bpref                 	24	1.0000
# recip_rank            	24	1.0000
# iprec_at_recall_0.00  	24	1.0000
# iprec_at_recall_0.10  	24	1.0000
# iprec_at_recall_0.20  	24	1.0000
# iprec_at_recall_0.30  	24	1.0000
# iprec_at_recall_0.40  	24	1.0000
# iprec_at_recall_0.50  	24	1.0000
# iprec_at_recall_0.60  	24	1.0000
# iprec_at_recall_0.70  	24	1.0000
# iprec_at_recall_0.80  	24	1.0000
# iprec_at_recall_0.90  	24	1.0000
# iprec_at_recall_1.00  	24	1.0000
# P_5                   	24	0.2000
# P_10                  	24	0.1000
# P_15                  	24	0.0667
# P_20                  	24	0.0500
# P_30                  	24	0.0333
# P_100                 	24	0.0100
# P_200                 	24	0.0050
# P_500                 	24	0.0020
# P_1000                	24	0.0010
# num_ret               	26	25
# num_rel               	26	3
# num_rel_ret           	26	1
# map                   	26	0.1111
# Rprec                 	26	0.3333
# bpref                 	26	0.1111
# recip_rank            	26	0.3333
# iprec_at_recall_0.00  	26	0.3333
# iprec_at_recall_0.10  	26	0.3333
# iprec_at_recall_0.20  	26	0.3333
# iprec_at_recall_0.30  	26	0.3333
# iprec_at_recall_0.40  	26	0.0000
# iprec_at_recall_0.50  	26	0.0000
# iprec_at_recall_0.60  	26	0.0000
# iprec_at_recall_0.70  	26	0.0000
# iprec_at_recall_0.80  	26	0.0000
# iprec_at_recall_0.90  	26	0.0000
# iprec_at_recall_1.00  	26	0.0000
# P_5                   	26	0.2000
# P_10                  	26	0.1000
# P_15                  	26	0.0667
# P_20                  	26	0.0500
# P_30                  	26	0.0333
# P_100                 	26	0.0100
# P_200                 	26	0.0050
# P_500                 	26	0.0020
# P_1000                	26	0.0010
# num_ret               	28	22
# num_rel               	28	2
# num_rel_ret           	28	0
# map                   	28	0.0000
# Rprec                 	28	0.0000
# bpref                 	28	0.0000
# recip_rank            	28	0.0000
# iprec_at_recall_0.00  	28	0.0000
# iprec_at_recall_0.10  	28	0.0000
# iprec_at_recall_0.20  	28	0.0000
# iprec_at_recall_0.30  	28	0.0000
# iprec_at_recall_0.40  	28	0.0000
# iprec_at_recall_0.50  	28	0.0000
# iprec_at_recall_0.60  	28	0.0000
# iprec_at_recall_0.70  	28	0.0000
# iprec_at_recall_0.80  	28	0.0000
# iprec_at_recall_0.90  	28	0.0000
# iprec_at_recall_1.00  	28	0.0000
# P_5                   	28	0.0000
# P_10                  	28	0.0000
# P_15                  	28	0.0000
# P_20                  	28	0.0000
# P_30                  	28	0.0000
# P_100                 	28	0.0000
# P_200                 	28	0.0000
# P_500                 	28	0.0000
# P_1000                	28	0.0000
# num_ret               	4	12
# num_rel               	4	4
# num_rel_ret           	4	1
# map                   	4	0.0312
# Rprec                 	4	0.0000
# bpref                 	4	0.0000
# recip_rank            	4	0.1250
# iprec_at_recall_0.00  	4	0.1250
# iprec_at_recall_0.10  	4	0.1250
# iprec_at_recall_0.20  	4	0.1250
# iprec_at_recall_0.30  	4	0.0000
# iprec_at_recall_0.40  	4	0.0000
# iprec_at_recall_0.50  	4	0.0000
# iprec_at_recall_0.60  	4	0.0000
# iprec_at_recall_0.70  	4	0.0000
# iprec_at_recall_0.80  	4	0.0000
# iprec_at_recall_0.90  	4	0.0000
# iprec_at_recall_1.00  	4	0.0000
# P_5                   	4	0.0000
# P_10                  	4	0.1000
# P_15                  	4	0.0667
# P_20                  	4	0.0500
# P_30                  	4	0.0333
# P_100                 	4	0.0100
# P_200                 	4	0.0050
# P_500                 	4	0.0020
# P_1000                	4	0.0010
# num_ret               	6	5
# num_rel               	6	1
# num_rel_ret           	6	0
# map                   	6	0.0000
# Rprec                 	6	0.0000
# bpref                 	6	0.0000
# recip_rank            	6	0.0000
# iprec_at_recall_0.00  	6	0.0000
# iprec_at_recall_0.10  	6	0.0000
# iprec_at_recall_0.20  	6	0.0000
# iprec_at_recall_0.30  	6	0.0000
# iprec_at_recall_0.40  	6	0.0000
# iprec_at_recall_0.50  	6	0.0000
# iprec_at_recall_0.60  	6	0.0000
# iprec_at_recall_0.70  	6	0.0000
# iprec_at_recall_0.80  	6	0.0000
# iprec_at_recall_0.90  	6	0.0000
# iprec_at_recall_1.00  	6	0.0000
# P_5                   	6	0.0000
# P_10                  	6	0.0000
# P_15                  	6	0.0000
# P_20                  	6	0.0000
# P_30                  	6	0.0000
# P_100                 	6	0.0000
# P_200                 	6	0.0000
# P_500                 	6	0.0000
# P_1000                	6	0.0000
# num_ret               	7	7
# num_rel               	7	3
# num_rel_ret           	7	0
# map                   	7	0.0000
# Rprec                 	7	0.0000
# bpref                 	7	0.0000
# recip_rank            	7	0.0000
# iprec_at_recall_0.00  	7	0.0000
# iprec_at_recall_0.10  	7	0.0000
# iprec_at_recall_0.20  	7	0.0000
# iprec_at_recall_0.30  	7	0.0000
# iprec_at_recall_0.40  	7	0.0000
# iprec_at_recall_0.50  	7	0.0000
# iprec_at_recall_0.60  	7	0.0000
# iprec_at_recall_0.70  	7	0.0000
# iprec_at_recall_0.80  	7	0.0000
# iprec_at_recall_0.90  	7	0.0000
# iprec_at_recall_1.00  	7	0.0000
# P_5                   	7	0.0000
# P_10                  	7	0.0000
# P_15                  	7	0.0000
# P_20                  	7	0.0000
# P_30                  	7	0.0000
# P_100                 	7	0.0000
# P_200                 	7	0.0000
# P_500                 	7	0.0000
# P_1000                	7	0.0000
# num_ret               	9	2
# num_rel               	9	1
# num_rel_ret           	9	0
# map                   	9	0.0000
# Rprec                 	9	0.0000
# bpref                 	9	0.0000
# recip_rank            	9	0.0000
# iprec_at_recall_0.00  	9	0.0000
# iprec_at_recall_0.10  	9	0.0000
# iprec_at_recall_0.20  	9	0.0000
# iprec_at_recall_0.30  	9	0.0000
# iprec_at_recall_0.40  	9	0.0000
# iprec_at_recall_0.50  	9	0.0000
# iprec_at_recall_0.60  	9	0.0000
# iprec_at_recall_0.70  	9	0.0000
# iprec_at_recall_0.80  	9	0.0000
# iprec_at_recall_0.90  	9	0.0000
# iprec_at_recall_1.00  	9	0.0000
# P_5                   	9	0.0000
# P_10                  	9	0.0000
# P_15                  	9	0.0000
# P_20                  	9	0.0000
# P_30                  	9	0.0000
# P_100                 	9	0.0000
# P_200                 	9	0.0000
# P_500                 	9	0.0000
# P_1000                	9	0.0000
# runid                 	all	test
# num_q                 	all	14
# num_ret               	all	151
# num_rel               	all	33
# num_rel_ret           	all	7
# map                   	all	0.1971
# gm_map                	all	0.0015
# Rprec                 	all	0.1667
# bpref                 	all	0.1508
# recip_rank            	all	0.2196
# iprec_at_recall_0.00  	all	0.2196
# iprec_at_recall_0.10  	all	0.2196
# iprec_at_recall_0.20  	all	0.2196
# iprec_at_recall_0.30  	all	0.2107
# iprec_at_recall_0.40  	all	0.1869
# iprec_at_recall_0.50  	all	0.1869
# iprec_at_recall_0.60  	all	0.1869
# iprec_at_recall_0.70  	all	0.1869
# iprec_at_recall_0.80  	all	0.1869
# iprec_at_recall_0.90  	all	0.1869
# iprec_at_recall_1.00  	all	0.1869
# P_5                   	all	0.0714
# P_10                  	all	0.0500
# P_15                  	all	0.0333
# P_20                  	all	0.0250
# P_30                  	all	0.0167
# P_100                 	all	0.0050
# P_200                 	all	0.0025
# P_500                 	all	0.0010
# P_1000                	all	0.0005

# %% [markdown]
# ### Q2 (b): Provide answer to Q2 (b) here [markdown cell]
# How well did the baseline Whoosh system do on your chosen measure? [Provide the number.]
#
# Topic | Measure | Value
# --- | --- | ---
# 1 | map | 0
# 10 | map | 0.1667
# 14 | map | 0.25
# 16 | map | 0
# 18 | map | 1
# 2 | map | 0
# 22 | map | 0.2
# 24 | map | 1
# 26 | map | 0.1111
# 28 | map | 0
# 4 | map | 0.0312
# 6 | map | 0
# 7 | map | 0
# 9 | map | 0
# **all** | **map** | **0.1971**
# **all** | **gm_map** | **0.0015**
#
# <br><br>
# **Performance:** The baseline Whoosh system did not performe well on the gm_map with score of 0.0015, overall map with 0.1971
# <br><br>
# ***Note: The result excluded topic #19 since, by default, TREC_EVAL does not consider un-retrieable queries (with comma inside).***

# %% [markdown]
# ### Q2 (c): Provide answer to Q2(c) here [markdown cell]
# Are there any particular topics where it did very well, or very badly? [If so, list a few topic IDs for each]
#
# **Yes there are some particular topics performing in extreme cases.**
# <br><br>
# **VERY WELL(MAP score 1.0000)**
# - #18 Shipwrecks
# - #24 Air Bag Sfety
#
#
# **VERY BADLY(MAP score 0.0000)**
# - #1 mining gold silver coal
# - #2 juvenile delinquency
# - #6 physical therapists
# - #7 cotton industry
# - #9 genealogy searches
# - #16 Emergency and disaster preparedness assistance
# - #28 Early Childhood Education

# %% [markdown]
# ## Question 3

# %% [markdown]
# ### Q3 (a): Provide answer to Q3 (a) here [markdown cell]
# What do you think would improve Whoosh’s performance on this test collection, and why?
#
# **Chosen query:** topic #16: Emergency and disaster preparedness assistance
# <br><br>
# In Q2, we got the total number of files = len(filesToIndex) = 4078
# <br><br>
# **Other measures in TREC_EVAL:**
# - num_rel_ret(# revelent retrieved) =  0 (True Positive)
# - num_ret(# retrieved)&emsp;&emsp;&emsp;&emsp;&emsp;&nbsp;&nbsp; = 7 (False Positive)
# - num_rel(# revelent)&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; = 7 (False Negative)
#
#
# **Generated Confusion Matrix:**
#
# Confusion Matrix | Relevant | Non-Relevant
# --- | --- | ---
# *Retrieved* | 0 | 7
# *Not Retrieved* | 7 | 4064
#
# **False Positive**
# - G00-34-3591274
# - G00-05-0719078
# - G00-92-2053892
# - G00-70-2681284
# - G00-33-2857182
# - G00-51-3264753
# - G00-32-1907807
#
# **False Negative**
# - G00-03-0589290
# - G00-21-0494028
# - G00-21-2114990
# - G00-32-0551737
# - G00-86-3719816
# - G00-92-2974327
# - G00-99-0140748
#
#
# Taking a detailed look at the document:
# - False Positive document example ***G00-32-1907807***, an irrelevant document that has been ranked, does contain all terms in the query.
# - False Negative document example ***G00-99-0140748***, a relevant document that has not been ranked, contains:
#   *  variations of "Emergency" - eg: "emergency", "Emergencies"
#   *  upper case in "disaster" & "preparedness"
#   *  too many stop word "and" (39 times)
#   *  no "assistance"
#
# Therefore, using customized analyzer with default vanilla tokenizer, lowercase filter, stopword filter, stemming and lemmatizing the index; searching for any term(s) instead of all terms, should provide better search results

# %%
sampleQuery = QP_Q2.parse("Emergency and disaster preparedness assistance") # parse topic 16
sampleQueryResults = SEARCHER_Q2.search(sampleQuery, limit=None)
# inspect the result:
# for each document print the rank and the score
for (docnum, result) in enumerate(sampleQueryResults):
    score = sampleQueryResults.score(docnum)
    fileName = os.path.basename(result["file_path"])
    print(fileName, docnum, score)
# Out:
# G00-34-3591274 0 34.092075576251
# G00-05-0719078 1 32.195485675325315
# G00-92-2053892 2 27.13176387951665
# G00-70-2681284 3 26.574622331662233
# G00-33-2857182 4 21.813916494265353
# G00-51-3264753 5 10.948532555349608
# G00-32-1907807 6 10.008862397603384

# %% [markdown]
# ### Q3 (b): Write your code below

# %% [markdown]
# #### Customize filter

# %%
import nltk
from nltk.stem import *

# download required resources
nltk.download("wordnet")

# Inititlizing filter, will run for both the index and the query
from whoosh.analysis import Filter
class CustomFilter(Filter):
    is_morph = True
    def __init__(self, filterFunc, *args, **kwargs):
        self.customFilter = filterFunc
        self.args = args
        self.kwargs = kwargs
    def __eq__(self):
        return (other
                and self.__class__ is other.__class__)
    def __call__(self, tokens):
        for t in tokens:
            if t.mode == 'query': # if called by query parser
                t.text = self.customFilter(t.text, *self.args, **self.kwargs)
                yield t
            else: # == 'index' if called by indexer
                t.text = self.customFilter(t.text, *self.args, **self.kwargs)
                yield t
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\austi\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# we'll compare two stemmers and a lemmatizer
lrStem = LancasterStemmer()
sbStem = SnowballStemmer("english")
wnLemm = WordNetLemmatizer()

# %%
#make a customerized analyzer with regextokenizer; lowercase; common words; stemmer
# tested lrStem out performed other NLTK measures
# we added IntraWordFilter to break phrase in #19 to improve overall performace (it is not originally needed for #16)
myAnalyzer = RegexTokenizer() | LowercaseFilter() | IntraWordFilter() | StopFilter() | StemFilter() | CustomFilter(lrStem.stem)

# %%
# define a Schema with the new analyzer
mySchema2 = Schema(file_path = ID(stored=True),
                   file_content = TEXT(analyzer = myAnalyzer))

# create the index based on the new schema
INDEX_Q3 = createIndex(mySchema2)

# %%
addFilesToIndex(INDEX_Q3, filesToIndex)
# Out:
# already indexed: 1000
# already indexed: 2000
# already indexed: 3000
# already indexed: 4000
# done indexing, time spent: 62.18s.

# %%
# define a query parser for the field "file_content" in the index
# reconfigured QP to OrGroup with scailling factor on the bonus 0.65
QP_Q3 = QueryParser("file_content", schema=INDEX_Q3.schema, group=qparser.OrGroup.factory(0.65))
SEARCHER_Q3= INDEX_Q3.searcher()
trecEval(TOPIC_FILE, QRELS_FILE, QP_Q3, SEARCHER_Q3)
# Out:
# num_ret               	1	469
# num_rel               	1	5
# num_rel_ret           	1	5
# map                   	1	0.0673
# Rprec                 	1	0.0000
# bpref                 	1	0.0000
# recip_rank            	1	0.0556
# iprec_at_recall_0.00  	1	0.1034
# iprec_at_recall_0.10  	1	0.1034
# iprec_at_recall_0.20  	1	0.1034
# iprec_at_recall_0.30  	1	0.1034
# iprec_at_recall_0.40  	1	0.1034
# iprec_at_recall_0.50  	1	0.1034
# iprec_at_recall_0.60  	1	0.1034
# iprec_at_recall_0.70  	1	0.0435
# iprec_at_recall_0.80  	1	0.0435
# iprec_at_recall_0.90  	1	0.0431
# iprec_at_recall_1.00  	1	0.0431
# P_5                   	1	0.0000
# P_10                  	1	0.0000
# P_15                  	1	0.0000
# P_20                  	1	0.0500
# P_30                  	1	0.1000
# P_100                 	1	0.0400
# P_200                 	1	0.0250
# P_500                 	1	0.0100
# P_1000                	1	0.0050
# num_ret               	10	490
# num_rel               	10	1
# num_rel_ret           	10	1
# map                   	10	0.2500
# Rprec                 	10	0.0000
# bpref                 	10	0.0000
# recip_rank            	10	0.2500
# iprec_at_recall_0.00  	10	0.2500
# iprec_at_recall_0.10  	10	0.2500
# iprec_at_recall_0.20  	10	0.2500
# iprec_at_recall_0.30  	10	0.2500
# iprec_at_recall_0.40  	10	0.2500
# iprec_at_recall_0.50  	10	0.2500
# iprec_at_recall_0.60  	10	0.2500
# iprec_at_recall_0.70  	10	0.2500
# iprec_at_recall_0.80  	10	0.2500
# iprec_at_recall_0.90  	10	0.2500
# iprec_at_recall_1.00  	10	0.2500
# P_5                   	10	0.2000
# P_10                  	10	0.1000
# P_15                  	10	0.0667
# P_20                  	10	0.0500
# P_30                  	10	0.0333
# P_100                 	10	0.0100
# P_200                 	10	0.0050
# P_500                 	10	0.0020
# P_1000                	10	0.0010
# num_ret               	14	315
# num_rel               	14	1
# num_rel_ret           	14	1
# map                   	14	1.0000
# Rprec                 	14	1.0000
# bpref                 	14	1.0000
# recip_rank            	14	1.0000
# iprec_at_recall_0.00  	14	1.0000
# iprec_at_recall_0.10  	14	1.0000
# iprec_at_recall_0.20  	14	1.0000
# iprec_at_recall_0.30  	14	1.0000
# iprec_at_recall_0.40  	14	1.0000
# iprec_at_recall_0.50  	14	1.0000
# iprec_at_recall_0.60  	14	1.0000
# iprec_at_recall_0.70  	14	1.0000
# iprec_at_recall_0.80  	14	1.0000
# iprec_at_recall_0.90  	14	1.0000
# iprec_at_recall_1.00  	14	1.0000
# P_5                   	14	0.2000
# P_10                  	14	0.1000
# P_15                  	14	0.0667
# P_20                  	14	0.0500
# P_30                  	14	0.0333
# P_100                 	14	0.0100
# P_200                 	14	0.0050
# P_500                 	14	0.0020
# P_1000                	14	0.0010
# num_ret               	16	1111
# num_rel               	16	7
# num_rel_ret           	16	7
# map                   	16	0.1552
# Rprec                 	16	0.0000
# bpref                 	16	0.0000
# recip_rank            	16	0.0833
# iprec_at_recall_0.00  	16	0.1905
# iprec_at_recall_0.10  	16	0.1905
# iprec_at_recall_0.20  	16	0.1905
# iprec_at_recall_0.30  	16	0.1905
# iprec_at_recall_0.40  	16	0.1905
# iprec_at_recall_0.50  	16	0.1905
# iprec_at_recall_0.60  	16	0.1613
# iprec_at_recall_0.70  	16	0.1613
# iprec_at_recall_0.80  	16	0.1579
# iprec_at_recall_0.90  	16	0.1522
# iprec_at_recall_1.00  	16	0.1522
# P_5                   	16	0.0000
# P_10                  	16	0.0000
# P_15                  	16	0.1333
# P_20                  	16	0.1500
# P_30                  	16	0.1333
# P_100                 	16	0.0700
# P_200                 	16	0.0350
# P_500                 	16	0.0140
# P_1000                	16	0.0070
# num_ret               	18	32
# num_rel               	18	1
# num_rel_ret           	18	1
# map                   	18	1.0000
# Rprec                 	18	1.0000
# bpref                 	18	1.0000
# recip_rank            	18	1.0000
# iprec_at_recall_0.00  	18	1.0000
# iprec_at_recall_0.10  	18	1.0000
# iprec_at_recall_0.20  	18	1.0000
# iprec_at_recall_0.30  	18	1.0000
# iprec_at_recall_0.40  	18	1.0000
# iprec_at_recall_0.50  	18	1.0000
# iprec_at_recall_0.60  	18	1.0000
# iprec_at_recall_0.70  	18	1.0000
# iprec_at_recall_0.80  	18	1.0000
# iprec_at_recall_0.90  	18	1.0000
# iprec_at_recall_1.00  	18	1.0000
# P_5                   	18	0.2000
# P_10                  	18	0.1000
# P_15                  	18	0.0667
# P_20                  	18	0.0500
# P_30                  	18	0.0333
# P_100                 	18	0.0100
# P_200                 	18	0.0050
# P_500                 	18	0.0020
# P_1000                	18	0.0010
# num_ret               	19	628
# num_rel               	19	2
# num_rel_ret           	19	1
# map                   	19	0.5000
# Rprec                 	19	0.5000
# bpref                 	19	0.5000
# recip_rank            	19	1.0000
# iprec_at_recall_0.00  	19	1.0000
# iprec_at_recall_0.10  	19	1.0000
# iprec_at_recall_0.20  	19	1.0000
# iprec_at_recall_0.30  	19	1.0000
# iprec_at_recall_0.40  	19	1.0000
# iprec_at_recall_0.50  	19	1.0000
# iprec_at_recall_0.60  	19	0.0000
# iprec_at_recall_0.70  	19	0.0000
# iprec_at_recall_0.80  	19	0.0000
# iprec_at_recall_0.90  	19	0.0000
# iprec_at_recall_1.00  	19	0.0000
# P_5                   	19	0.2000
# P_10                  	19	0.1000
# P_15                  	19	0.0667
# P_20                  	19	0.0500
# P_30                  	19	0.0333
# P_100                 	19	0.0100
# P_200                 	19	0.0050
# P_500                 	19	0.0020
# P_1000                	19	0.0010
# num_ret               	2	59
# num_rel               	2	2
# num_rel_ret           	2	2
# map                   	2	0.5385
# Rprec                 	2	0.5000
# bpref                 	2	0.5000
# recip_rank            	2	1.0000
# iprec_at_recall_0.00  	2	1.0000
# iprec_at_recall_0.10  	2	1.0000
# iprec_at_recall_0.20  	2	1.0000
# iprec_at_recall_0.30  	2	1.0000
# iprec_at_recall_0.40  	2	1.0000
# iprec_at_recall_0.50  	2	1.0000
# iprec_at_recall_0.60  	2	0.0769
# iprec_at_recall_0.70  	2	0.0769
# iprec_at_recall_0.80  	2	0.0769
# iprec_at_recall_0.90  	2	0.0769
# iprec_at_recall_1.00  	2	0.0769
# P_5                   	2	0.2000
# P_10                  	2	0.1000
# P_15                  	2	0.0667
# P_20                  	2	0.0500
# P_30                  	2	0.0667
# P_100                 	2	0.0200
# P_200                 	2	0.0100
# P_500                 	2	0.0040
# P_1000                	2	0.0020
# num_ret               	22	468
# num_rel               	22	1
# num_rel_ret           	22	1
# map                   	22	0.0357
# Rprec                 	22	0.0000
# bpref                 	22	0.0000
# recip_rank            	22	0.0357
# iprec_at_recall_0.00  	22	0.0357
# iprec_at_recall_0.10  	22	0.0357
# iprec_at_recall_0.20  	22	0.0357
# iprec_at_recall_0.30  	22	0.0357
# iprec_at_recall_0.40  	22	0.0357
# iprec_at_recall_0.50  	22	0.0357
# iprec_at_recall_0.60  	22	0.0357
# iprec_at_recall_0.70  	22	0.0357
# iprec_at_recall_0.80  	22	0.0357
# iprec_at_recall_0.90  	22	0.0357
# iprec_at_recall_1.00  	22	0.0357
# P_5                   	22	0.0000
# P_10                  	22	0.0000
# P_15                  	22	0.0000
# P_20                  	22	0.0000
# P_30                  	22	0.0333
# P_100                 	22	0.0100
# P_200                 	22	0.0050
# P_500                 	22	0.0020
# P_1000                	22	0.0010
# num_ret               	24	689
# num_rel               	24	1
# num_rel_ret           	24	1
# map                   	24	1.0000
# Rprec                 	24	1.0000
# bpref                 	24	1.0000
# recip_rank            	24	1.0000
# iprec_at_recall_0.00  	24	1.0000
# iprec_at_recall_0.10  	24	1.0000
# iprec_at_recall_0.20  	24	1.0000
# iprec_at_recall_0.30  	24	1.0000
# iprec_at_recall_0.40  	24	1.0000
# iprec_at_recall_0.50  	24	1.0000
# iprec_at_recall_0.60  	24	1.0000
# iprec_at_recall_0.70  	24	1.0000
# iprec_at_recall_0.80  	24	1.0000
# iprec_at_recall_0.90  	24	1.0000
# iprec_at_recall_1.00  	24	1.0000
# P_5                   	24	0.2000
# P_10                  	24	0.1000
# P_15                  	24	0.0667
# P_20                  	24	0.0500
# P_30                  	24	0.0333
# P_100                 	24	0.0100
# P_200                 	24	0.0050
# P_500                 	24	0.0020
# P_1000                	24	0.0010
# num_ret               	26	589
# num_rel               	26	3
# num_rel_ret           	26	3
# map                   	26	0.1074
# Rprec                 	26	0.0000
# bpref                 	26	0.0000
# recip_rank            	26	0.1667
# iprec_at_recall_0.00  	26	0.1667
# iprec_at_recall_0.10  	26	0.1667
# iprec_at_recall_0.20  	26	0.1667
# iprec_at_recall_0.30  	26	0.1667
# iprec_at_recall_0.40  	26	0.0909
# iprec_at_recall_0.50  	26	0.0909
# iprec_at_recall_0.60  	26	0.0909
# iprec_at_recall_0.70  	26	0.0909
# iprec_at_recall_0.80  	26	0.0909
# iprec_at_recall_0.90  	26	0.0909
# iprec_at_recall_1.00  	26	0.0909
# P_5                   	26	0.0000
# P_10                  	26	0.1000
# P_15                  	26	0.0667
# P_20                  	26	0.0500
# P_30                  	26	0.0333
# P_100                 	26	0.0300
# P_200                 	26	0.0150
# P_500                 	26	0.0060
# P_1000                	26	0.0030
# num_ret               	28	1071
# num_rel               	28	2
# num_rel_ret           	28	2
# map                   	28	0.2262
# Rprec                 	28	0.0000
# bpref                 	28	0.0000
# recip_rank            	28	0.1667
# iprec_at_recall_0.00  	28	0.2857
# iprec_at_recall_0.10  	28	0.2857
# iprec_at_recall_0.20  	28	0.2857
# iprec_at_recall_0.30  	28	0.2857
# iprec_at_recall_0.40  	28	0.2857
# iprec_at_recall_0.50  	28	0.2857
# iprec_at_recall_0.60  	28	0.2857
# iprec_at_recall_0.70  	28	0.2857
# iprec_at_recall_0.80  	28	0.2857
# iprec_at_recall_0.90  	28	0.2857
# iprec_at_recall_1.00  	28	0.2857
# P_5                   	28	0.0000
# P_10                  	28	0.2000
# P_15                  	28	0.1333
# P_20                  	28	0.1000
# P_30                  	28	0.0667
# P_100                 	28	0.0200
# P_200                 	28	0.0100
# P_500                 	28	0.0040
# P_1000                	28	0.0020
# num_ret               	4	902
# num_rel               	4	4
# num_rel_ret           	4	4
# map                   	4	0.5614
# Rprec                 	4	0.5000
# bpref                 	4	0.5000
# recip_rank            	4	1.0000
# iprec_at_recall_0.00  	4	1.0000
# iprec_at_recall_0.10  	4	1.0000
# iprec_at_recall_0.20  	4	1.0000
# iprec_at_recall_0.30  	4	1.0000
# iprec_at_recall_0.40  	4	1.0000
# iprec_at_recall_0.50  	4	1.0000
# iprec_at_recall_0.60  	4	0.1429
# iprec_at_recall_0.70  	4	0.1429
# iprec_at_recall_0.80  	4	0.1026
# iprec_at_recall_0.90  	4	0.1026
# iprec_at_recall_1.00  	4	0.1026
# P_5                   	4	0.4000
# P_10                  	4	0.2000
# P_15                  	4	0.1333
# P_20                  	4	0.1000
# P_30                  	4	0.1000
# P_100                 	4	0.0400
# P_200                 	4	0.0200
# P_500                 	4	0.0080
# P_1000                	4	0.0040
# num_ret               	6	460
# num_rel               	6	1
# num_rel_ret           	6	1
# map                   	6	0.1667
# Rprec                 	6	0.0000
# bpref                 	6	0.0000
# recip_rank            	6	0.1667
# iprec_at_recall_0.00  	6	0.1667
# iprec_at_recall_0.10  	6	0.1667
# iprec_at_recall_0.20  	6	0.1667
# iprec_at_recall_0.30  	6	0.1667
# iprec_at_recall_0.40  	6	0.1667
# iprec_at_recall_0.50  	6	0.1667
# iprec_at_recall_0.60  	6	0.1667
# iprec_at_recall_0.70  	6	0.1667
# iprec_at_recall_0.80  	6	0.1667
# iprec_at_recall_0.90  	6	0.1667
# iprec_at_recall_1.00  	6	0.1667
# P_5                   	6	0.0000
# P_10                  	6	0.1000
# P_15                  	6	0.0667
# P_20                  	6	0.0500
# P_30                  	6	0.0333
# P_100                 	6	0.0100
# P_200                 	6	0.0050
# P_500                 	6	0.0020
# P_1000                	6	0.0010
# num_ret               	7	494
# num_rel               	7	3
# num_rel_ret           	7	2
# map                   	7	0.1778
# Rprec                 	7	0.0000
# bpref                 	7	0.0000
# recip_rank            	7	0.2000
# iprec_at_recall_0.00  	7	0.3333
# iprec_at_recall_0.10  	7	0.3333
# iprec_at_recall_0.20  	7	0.3333
# iprec_at_recall_0.30  	7	0.3333
# iprec_at_recall_0.40  	7	0.3333
# iprec_at_recall_0.50  	7	0.3333
# iprec_at_recall_0.60  	7	0.3333
# iprec_at_recall_0.70  	7	0.3333
# iprec_at_recall_0.80  	7	0.0000
# iprec_at_recall_0.90  	7	0.0000
# iprec_at_recall_1.00  	7	0.0000
# P_5                   	7	0.2000
# P_10                  	7	0.2000
# P_15                  	7	0.1333
# P_20                  	7	0.1000
# P_30                  	7	0.0667
# P_100                 	7	0.0200
# P_200                 	7	0.0100
# P_500                 	7	0.0040
# P_1000                	7	0.0020
# num_ret               	9	1856
# num_rel               	9	1
# num_rel_ret           	9	1
# map                   	9	0.0588
# Rprec                 	9	0.0000
# bpref                 	9	0.0000
# recip_rank            	9	0.0588
# iprec_at_recall_0.00  	9	0.0588
# iprec_at_recall_0.10  	9	0.0588
# iprec_at_recall_0.20  	9	0.0588
# iprec_at_recall_0.30  	9	0.0588
# iprec_at_recall_0.40  	9	0.0588
# iprec_at_recall_0.50  	9	0.0588
# iprec_at_recall_0.60  	9	0.0588
# iprec_at_recall_0.70  	9	0.0588
# iprec_at_recall_0.80  	9	0.0588
# iprec_at_recall_0.90  	9	0.0588
# iprec_at_recall_1.00  	9	0.0588
# P_5                   	9	0.0000
# P_10                  	9	0.0000
# P_15                  	9	0.0000
# P_20                  	9	0.0500
# P_30                  	9	0.0333
# P_100                 	9	0.0100
# P_200                 	9	0.0050
# P_500                 	9	0.0020
# P_1000                	9	0.0010
# runid                 	all	test
# num_q                 	all	15
# num_ret               	all	9633
# num_rel               	all	35
# num_rel_ret           	all	33
# map                   	all	0.3897
# gm_map                	all	0.2427
# Rprec                 	all	0.3000
# bpref                 	all	0.3000
# recip_rank            	all	0.4789
# iprec_at_recall_0.00  	all	0.5061
# iprec_at_recall_0.10  	all	0.5061
# iprec_at_recall_0.20  	all	0.5061
# iprec_at_recall_0.30  	all	0.5061
# iprec_at_recall_0.40  	all	0.5010
# iprec_at_recall_0.50  	all	0.5010
# iprec_at_recall_0.60  	all	0.3137
# iprec_at_recall_0.70  	all	0.3097
# iprec_at_recall_0.80  	all	0.2846
# iprec_at_recall_0.90  	all	0.2842
# iprec_at_recall_1.00  	all	0.2842
# P_5                   	all	0.1200
# P_10                  	all	0.0933
# P_15                  	all	0.0711
# P_20                  	all	0.0633
# P_30                  	all	0.0556
# P_100                 	all	0.0213
# P_200                 	all	0.0110
# P_500                 	all	0.0044
# P_1000                	all	0.0022

# %%
sampleQuery = QP_Q3.parse("Emergency and disaster preparedness assistance") # parse topic 16
sampleQueryResults = SEARCHER_Q3.search(sampleQuery, limit=None)
# inspect the result:
# for each document print the rank and the score
for (docnum, result) in enumerate(sampleQueryResults):
    score = sampleQueryResults.score(docnum)
    fileName = os.path.basename(result["file_path"])
    print(fileName, docnum, score)
# Out:
# G00-68-3661801 0 18.599747640697878
# G00-34-3591274 1 18.479768692710223
# G00-03-2245885 2 17.751934884382294
# G00-70-2681284 3 17.683326346242325
# G00-45-0006211 4 17.469466366514794
# G00-88-2853984 5 17.469466366514794
# G00-05-0719078 6 17.43829971560651
# G00-84-2647789 7 17.360890515680687
# G00-92-2053892 8 16.66956198606738
# G00-20-3839216 9 16.602779963567237
# G00-93-0870338 10 16.3046950063232
# G00-21-0494028 11 16.184500620880957
# G00-21-2114990 12 16.042227201700257
# G00-46-3010333 13 15.652530245869027
# G00-77-1693859 14 15.627349583551965
# G00-86-3719816 15 15.626463396210132
# G00-14-0931254 16 15.49111020561254
# G00-53-0263242 17 15.140227721793492
# G00-60-2564326 18 14.56206832027543
# G00-33-2857182 19 14.355026017168779
# G00-32-0551737 20 14.248538083393573
# G00-02-0866559 21 14.082025972000068
# G00-09-1393028 22 13.96537578435461
# G00-75-3633903 23 13.93301974889707
# G00-97-3418169 24 13.875352442130099
# G00-50-1075346 1072 1.2512018327171315
# G00-15-3695921 1073 1.2377607304250948
# G00-86-1693753 1074 1.2333575550680993
# G00-52-3079304 1075 1.2137235052841109
# G00-31-1130222 1076 1.211570406237098
# G00-37-2777794 1077 1.211570406237098
# G00-29-2968932 1078 1.2046309491496432
# G00-96-1395116 1079 1.2046309491496432
# G00-38-2705227 1080 1.1864654612314183
# G00-42-2097415 1081 1.1864654612314183
# G00-55-1952930 1082 1.1579005601620476
# G00-39-3477058 1083 1.1106550391478764
# G00-26-4176011 1084 1.085875355375535
# G00-45-4032177 1085 1.0615980464619885
# G00-70-3118212 1086 1.0372760337934908
# G00-93-1783036 1087 1.0372760337934908
# G00-57-3600665 1088 0.9971149076491757
# G00-94-0708359 1089 0.9778445881194605
# G00-42-1455285 1090 0.9723211517559358
# G00-98-1047338 1091 0.967191479704935
# G00-80-2865414 1092 0.9222878324799851
# G00-70-3168895 1093 0.916125636914358
# G00-47-2967546 1094 0.8769543498762731
# G00-73-3314008 1095 0.8706099665033147
# G00-63-2233776 1096 0.8470453640750437
# G00-25-3027752 1097 0.79563969704628
# G00-73-2660773 1098 0.7756682466301412
# G00-39-4066050 1099 0.7371910044876743
# G00-92-0142623 1100 0.7184201424167708
# G00-79-2569923 1101 0.6595443105883256
# G00-76-2323292 1102 0.6594936860703478
# G00-43-3607125 1103 0.6327946824530696
# G00-91-3181951 1104 0.6277260637096731
# G00-26-1962814 1105 0.6131976602251815
# G00-73-3170442 1106 0.5808167192347569
# G00-25-1928405 1107 0.5570003014444166
# G00-33-0053624 1108 0.4487493199964806
# G00-43-1143881 1109 0.4397732496565307
# G00-60-0631416 1110 0.3540331789416163

# %% [markdown]
# ### Q3 (c): Provide answer to Q3 (c) here [markdown cell]
# **Modification**
# - Added customized filter for the analyzer when generating schema for indexing, including stemming, lowercase, stopwards, NLTK stemmer
#   * added IntraWordFilter to break phrase in #19 to improve overall performace (not originally needed for #16).
# - Reconfigured the QueryParser to use OR instread of AND using "group" keyward with scaling factor for repeated word bonus of 0.65 after many trials.
#
# Topic | Measure | Value_in_Q2 | Value_in_Q3 | Improvement
# --- | --- | --- | --- | ---
# 1 | map | 0 | 0.0673 | +
# 10 | map | 0.1667 | 0.2500 | +
# 14 | map | 0.2500 | 1 | +
# ***16*** | ***map*** | ***0*** | ***0.1552*** | ***+***
# 18 | map | 1 | 1 |
# 19 | map | N/A | 0.5000 | +
# 2 | map | 0 | 0.5385| +
# 22 | map | 0.2000 | 0.0357| -
# 24 | map | 1 | 1|
# 26 | map | 0.1111 | 0.1074| -
# 28 | map | 0 | 0.2262 | +
# 4 | map | 0.0312 | 0.5614| +
# 6 | map | 0 | 0.1667 | +
# 7 | map | 0 | 0.1778 | +
# 9 | map | 0 | 0.0588 | +
# **all** | **map** | **0.1971** | **0.3897** | ***104.35%***
# **all** | **gm_map** | **0.0015** | **0.2427** | ***16080%***
#
# **Confusion Matrix (topic #16): topic#16's map (0->0.1552)**
#
# Confusion Matrix | Relevant | Non-Relevant
# --- | --- | ---
# *Retrieved* | 7 | 1104
# *Not Retrieved* | 0 | 2967
#
# **False Positive:**
# <br>There are **1111** retrieved documents in total but **1104** of them are not relevant, precision dropped largely.
# - first True Positive document ***G00-21-0494028*** only ranked **12th(recip_rank = 0.0833)** in the total retrieved document.
# - first False Positive document ***G00-68-3661801*** that ranked **1st** in the total retrieved documents contained dominantly more # of occurrences of "emergency" other than other words in the query​.
#
# **False Negative:**
# <br>All False Negative document eliminated.<br>
# ***Noted: OR parser returned considerably more retrieved document, making sure a high recall while largely decreasing precision.***

# %% [markdown]
# ### Q3 (d): Provide answer to Q3 (d) here [markdown cell]
# YES, refer to table in 3c)

# %% [markdown]
# ### Q3 (e): Provide answer to Q3 (e) here [markdown cell]
# YES, refer to table in 3c)

# %% [markdown]
# ### Q3 (f): Provide answer to Q3 (f) here [markdown cell]
#
# Although the customized analyzer with reconfigured QueryParser yielded considerably more retrieved documents which led to a high recall with low precision, the overall performance for measurement map, gm_map and topic #16's map increased largely, implying a good modification from Q2. Highly improved map(104.35%) and gm_map(16080%) value also reflected a generally higher ranked relevant documents in the retrieved documents. Noteworthly, few query results performed worse than Q2 while rest improved dramatically.

# %% [markdown]
# ## Question 4 (Graduate Students)

# %%
GRAD_STUDENT = True # change to True if you are a grad student

# %% [markdown]
# ### Q4 (a): Provide answer to Q4 (a) here [markdown cell]
#
# **Chosen query:** topic #16: Emergency and disaster preparedness assistance
# <br><br>
# **Confusion Matrix (topic #16):**
#
# Confusion Matrix | Relevant | Non-Relevant
# --- | --- | ---
# *Retrieved* | 0 | 7
# *Not Retrieved* | 7 | 4064
#
# **False Positive**
# - G00-34-3591274
# - G00-05-0719078
# - G00-92-2053892
# - G00-70-2681284
# - G00-33-2857182
# - G00-51-3264753
# - G00-32-1907807
#
# **False Negative**
# - G00-03-0589290
# - G00-21-0494028
# - G00-21-2114990
# - G00-32-0551737
# - G00-86-3719816
# - G00-92-2974327
# - G00-99-0140748
#
#
# Taking a detailed look at the document:
# - False Positive document example ***G00-32-1907807***, an irrelevant document that has been ranked, does contain all terms in the query.
# - False Negative document example ***G00-99-0140748***, a relevant document that has not been ranked, contains:
#   *  variations of "Emergency" - eg: "emergency", "Emergencies"
#   *  upper case in "disaster" & "preparedness"
#   *  too many stop word "and" (39 times)
#   *  no "assistance"
#
# Therefore, using customized analyzer with default vanilla tokenizer, lowercase filter, stopword filter, stemming and lemmatizing the index; searching for any term(s) instead of all terms, should provide better search results.
#
#
#
# **In Q3 we are focusing on improving Parser by customizing analyzer in the schema and reconfiguring QueryParser. Now we can take a look at enhancing measurement by modifying Searcher.**
#
# **Normally the searching results are sorted by the default scoring function BM25F. Parameters of tunning fall into B and K1.**
# - B: the degree of field-length normalization.
# - K1: how quickly an increase in term frequency results in term frequency saturation.
#
# **By tunning the parameters, the searcher should be optimized with a  most appropriate degree of field-length normalization and term frequency saturation, outputing better measurements compared to Q3.**
#
# Source: https://www.elastic.co/guide/en/elasticsearch/guide/current/pluggable-similarites.html

# %% [markdown]
# ### Q4 (b): Write your code below

# %%
# define a Schema with the new analyzer
mySchema2 = Schema(file_path = ID(stored=True),
                   file_content = TEXT(analyzer = myAnalyzer))

# create the index based on the new schema
INDEX_Q4 = createIndex(mySchema2)

# %%
addFilesToIndex(INDEX_Q4, filesToIndex)
# Out:
# already indexed: 1000
# already indexed: 2000
# already indexed: 3000
# already indexed: 4000
# done indexing, time spent: 69.88s.

# %%
def trecEval_map_all(topicFile, qrelsFile, queryParser, searcher):
    # Load topic file - a list of topics(search phrases) used for evalutation
    with open(topicFile, "r") as tf:
        topics = tf.read().splitlines()

    # create an output file to which we'll write our results
    tempOutputFile = tempfile.mkstemp()[1]
    with open(tempOutputFile, "w") as outputTRECFile:
        # for each evaluated topic:
        # build a query and record the results in the file in TREC_EVAL format
        for topic in topics:
            topic_id, topic_phrase = tuple(topic.split(" ", 1))
            topicQuery = queryParser.parse(topic_phrase)
            topicResults = searcher.search(topicQuery, limit=None)
            for (docnum, result) in enumerate(topicResults):
                score = topicResults.score(docnum)
                outputTRECFile.write("%s Q0 %s %d %lf test\n" % (topic_id, os.path.basename(result["file_path"]), docnum, score))
    
    result = subprocess.run([TREC_EVAL, '-q', qrelsFile, tempOutputFile], stdout=subprocess.PIPE)
    
    result_map = []
    result_temp = []
    result_text = result.stdout.decode()
    result_line = result_text.splitlines()
    for line in result_line:
        cleanWords = [word.strip(""" ,.*()[]!@#$%^&*{}?'`"-""") for word in line.split()]
        if any( "map" in s for s in cleanWords):
            result_map.append(cleanWords)
   


    map_temp = float(result_map[15][2])
    gm_temp = float(result_map[16][2])
    

    result_temp.append(map_temp)
    result_temp.append(gm_temp)

    return (result_temp)

# %%
# define a query parser for the field "file_content" in the index
QP_Q4 = QueryParser("file_content", schema=INDEX_Q4.schema,group=qparser.OrGroup.factory(0.65))
b = 0
k = 0

temp_best_map=[0,0]
temp_best_gm_map=[0,0]
temp_best_map_d={}
temp_best_gm_map_d={}

#running based on the score of map
while b < 101:
    while k < 101:
        w = scoring.BM25F(B=b*0.01, K1=k*0.1)
        searcher_temp = INDEX_Q4.searcher(weighting=w)
        result_temp = trecEval_map_all(TOPIC_FILE, QRELS_FILE, QP_Q4, searcher_temp)
        if result_temp[0] > temp_best_map[0]:
            temp_best_map = result_temp
            temp_best_map_d[(b,k)]=temp_best_map
            print("best map: " + str(temp_best_map_d[(b,k)][0])+", corresponding gm_map: " + str(temp_best_map_d[(b,k)][1]) +", b: "+str(b)+", k: "+str(k))
            
        k+=1
    b+=1
    k=0
    
print("finished searching, best map captured.")
# Out:
# best map: 0.0929, corresponding gm_map: 0.0606, b: 0, k: 0
# best map: 0.2678, corresponding gm_map: 0.1703, b: 0, k: 1
# best map: 0.2681, corresponding gm_map: 0.1749, b: 0, k: 10
# best map: 0.2682, corresponding gm_map: 0.1763, b: 0, k: 12
# best map: 0.2687, corresponding gm_map: 0.1774, b: 0, k: 13
# best map: 0.2743, corresponding gm_map: 0.181, b: 0, k: 14
# best map: 0.2749, corresponding gm_map: 0.1822, b: 0, k: 15
# best map: 0.2757, corresponding gm_map: 0.1836, b: 0, k: 16
# best map: 0.2759, corresponding gm_map: 0.1844, b: 0, k: 18
# best map: 0.2763, corresponding gm_map: 0.185, b: 0, k: 24
# best map: 0.277, corresponding gm_map: 0.1855, b: 0, k: 25
# best map: 0.2881, corresponding gm_map: 0.1908, b: 0, k: 26
# best map: 0.3067, corresponding gm_map: 0.183, b: 1, k: 1
# best map: 0.3103, corresponding gm_map: 0.1876, b: 1, k: 5
# best map: 0.3104, corresponding gm_map: 0.188, b: 1, k: 6
# best map: 0.3107, corresponding gm_map: 0.1889, b: 1, k: 7
# best map: 0.3112, corresponding gm_map: 0.1907, b: 1, k: 8
# best map: 0.3115, corresponding gm_map: 0.1915, b: 1, k: 9
# best map: 0.3116, corresponding gm_map: 0.1913, b: 1, k: 10
# best map: 0.3119, corresponding gm_map: 0.1932, b: 1, k: 12
# best map: 0.3126, corresponding gm_map: 0.1953, b: 1, k: 14
# best map: 0.3132, corresponding gm_map: 0.1966, b: 1, k: 15
# best map: 0.3238, corresponding gm_map: 0.2019, b: 1, k: 21
# best map: 0.3261, corresponding gm_map: 0.2054, b: 1, k: 24
# best map: 0.327, corresponding gm_map: 0.2071, b: 2, k: 24
# best map: 0.3271, corresponding gm_map: 0.2071, b: 2, k: 26
# best map: 0.3272, corresponding gm_map: 0.2062, b: 2, k: 61
# best map: 0.3275, corresponding gm_map: 0.2081, b: 3, k: 26
# best map: 0.3282, corresponding gm_map: 0.2082, b: 3, k: 54
# best map: 0.3283, corresponding gm_map: 0.2082, b: 3, k: 59
# best map: 0.329, corresponding gm_map: 0.2098, b: 4, k: 43
# best map: 0.3304, corresponding gm_map: 0.2096, b: 4, k: 69
# best map: 0.3305, corresponding gm_map: 0.2113, b: 5, k: 53
# best map: 0.332, corresponding gm_map: 0.2128, b: 5, k: 54
# best map: 0.3321, corresponding gm_map: 0.213, b: 5, k: 56
# best map: 0.3323, corresponding gm_map: 0.2032, b: 6, k: 7
# best map: 0.3329, corresponding gm_map: 0.205, b: 6, k: 8
# best map: 0.3335, corresponding gm_map: 0.2065, b: 6, k: 9
# best map: 0.334, corresponding gm_map: 0.2079, b: 6, k: 10
# best map: 0.3345, corresponding gm_map: 0.2092, b: 6, k: 11
# best map: 0.3353, corresponding gm_map: 0.2111, b: 6, k: 12
# best map: 0.3357, corresponding gm_map: 0.2126, b: 6, k: 15
# best map: 0.3359, corresponding gm_map: 0.2138, b: 6, k: 18
# best map: 0.3378, corresponding gm_map: 0.2176, b: 6, k: 22
# best map: 0.3387, corresponding gm_map: 0.2173, b: 6, k: 34
# best map: 0.3389, corresponding gm_map: 0.2178, b: 6, k: 35
# best map: 0.3393, corresponding gm_map: 0.2181, b: 6, k: 39
# best map: 0.3394, corresponding gm_map: 0.2182, b: 6, k: 42
# best map: 0.3417, corresponding gm_map: 0.2204, b: 6, k: 44
# best map: 0.3418, corresponding gm_map: 0.2206, b: 6, k: 53
# best map: 0.3421, corresponding gm_map: 0.2168, b: 7, k: 15
# best map: 0.3424, corresponding gm_map: 0.2173, b: 7, k: 17
# best map: 0.3425, corresponding gm_map: 0.2177, b: 7, k: 18
# best map: 0.3447, corresponding gm_map: 0.2216, b: 7, k: 22
# best map: 0.3449, corresponding gm_map: 0.2206, b: 7, k: 35
# best map: 0.345, corresponding gm_map: 0.2207, b: 7, k: 36
# best map: 0.3476, corresponding gm_map: 0.2238, b: 7, k: 37
# best map: 0.3478, corresponding gm_map: 0.2242, b: 7, k: 38
# best map: 0.3479, corresponding gm_map: 0.2245, b: 7, k: 39
# best map: 0.348, corresponding gm_map: 0.2245, b: 7, k: 42
# best map: 0.3673, corresponding gm_map: 0.2204, b: 7, k: 94
# best map: 0.3751, corresponding gm_map: 0.2266, b: 8, k: 83
# best map: 0.3817, corresponding gm_map: 0.235, b: 9, k: 74
# best map: 0.3827, corresponding gm_map: 0.2373, b: 10, k: 66
# best map: 0.3842, corresponding gm_map: 0.2409, b: 11, k: 58
# best map: 0.3843, corresponding gm_map: 0.2401, b: 11, k: 71
# best map: 0.3849, corresponding gm_map: 0.2417, b: 12, k: 64
# best map: 0.3868, corresponding gm_map: 0.2293, b: 25, k: 3
# best map: 0.3875, corresponding gm_map: 0.2328, b: 25, k: 4
# best map: 0.388, corresponding gm_map: 0.235, b: 25, k: 5
# best map: 0.3882, corresponding gm_map: 0.2294, b: 26, k: 2
# best map: 0.389, corresponding gm_map: 0.2364, b: 26, k: 5
# best map: 0.3893, corresponding gm_map: 0.2379, b: 26, k: 6
# best map: 0.3914, corresponding gm_map: 0.2413, b: 27, k: 6
# best map: 0.3925, corresponding gm_map: 0.2606, b: 27, k: 17
# best map: 0.3926, corresponding gm_map: 0.2609, b: 27, k: 18
# best map: 0.3927, corresponding gm_map: 0.2606, b: 27, k: 21
# best map: 0.393, corresponding gm_map: 0.2611, b: 27, k: 22
# best map: 0.3932, corresponding gm_map: 0.2624, b: 28, k: 22
# best map: 0.3933, corresponding gm_map: 0.2625, b: 28, k: 23
# best map: 0.3934, corresponding gm_map: 0.2628, b: 29, k: 22
# best map: 0.3936, corresponding gm_map: 0.2633, b: 29, k: 24
# best map: 0.3954, corresponding gm_map: 0.2524, b: 30, k: 9
# best map: 0.3961, corresponding gm_map: 0.2535, b: 31, k: 9
# best map: 0.3963, corresponding gm_map: 0.2541, b: 31, k: 10
# best map: 0.3981, corresponding gm_map: 0.2572, b: 32, k: 11
# best map: 0.3982, corresponding gm_map: 0.2573, b: 33, k: 11
# best map: 0.3984, corresponding gm_map: 0.2578, b: 33, k: 12
# best map: 0.3985, corresponding gm_map: 0.258, b: 34, k: 12
# best map: 0.3988, corresponding gm_map: 0.2589, b: 35, k: 14
# best map: 0.3989, corresponding gm_map: 0.2592, b: 36, k: 14
# best map: 0.4002, corresponding gm_map: 0.2619, b: 36, k: 15
# best map: 0.4033, corresponding gm_map: 0.2668, b: 36, k: 16
# best map: 0.4035, corresponding gm_map: 0.2671, b: 37, k: 16
# best map: 0.4055, corresponding gm_map: 0.27, b: 37, k: 17
# best map: 0.4066, corresponding gm_map: 0.2725, b: 38, k: 17
# best map: 0.4072, corresponding gm_map: 0.2736, b: 38, k: 18
# best map: 0.4073, corresponding gm_map: 0.2732, b: 39, k: 18
# best map: 0.4075, corresponding gm_map: 0.2736, b: 39, k: 19
# best map: 0.4077, corresponding gm_map: 0.2747, b: 39, k: 20
# best map: 0.4078, corresponding gm_map: 0.2744, b: 40, k: 21
# best map: 0.4079, corresponding gm_map: 0.2747, b: 42, k: 19
# best map: 0.408, corresponding gm_map: 0.2757, b: 43, k: 18
# best map: 0.4082, corresponding gm_map: 0.2761, b: 46, k: 22
# best map: 0.409, corresponding gm_map: 0.2768, b: 46, k: 23
# best map: 0.4094, corresponding gm_map: 0.2775, b: 46, k: 24
# best map: 0.4095, corresponding gm_map: 0.2776, b: 47, k: 24
# best map: 0.4096, corresponding gm_map: 0.278, b: 48, k: 24
# best map: 0.4097, corresponding gm_map: 0.2776, b: 49, k: 19
# best map: 0.4099, corresponding gm_map: 0.2785, b: 49, k: 24
# best map: 0.4108, corresponding gm_map: 0.2773, b: 49, k: 44
# best map: 0.411, corresponding gm_map: 0.2774, b: 50, k: 44
# best map: 0.4112, corresponding gm_map: 0.2778, b: 51, k: 44
# best map: 0.4113, corresponding gm_map: 0.2799, b: 52, k: 25
# best map: 0.4114, corresponding gm_map: 0.2772, b: 52, k: 45
# best map: 0.4115, corresponding gm_map: 0.2775, b: 52, k: 46
# best map: 0.4118, corresponding gm_map: 0.2777, b: 53, k: 45
# best map: 0.4119, corresponding gm_map: 0.2806, b: 55, k: 27
# best map: 0.412, corresponding gm_map: 0.281, b: 56, k: 26
# best map: 0.4121, corresponding gm_map: 0.2811, b: 56, k: 27
# finished searching, best map captured.

# %% [markdown]
# **best map: 0.4121, corresponding gm_map: 0.2811, b: 56, k: 27**
#
# ***B = 0.56, K1 = 2.7***

# %%
#runnign based on the score of gm_map
b = 0
k = 0
while b < 101:
    while k < 101:
        w = scoring.BM25F(B=b*0.02, K1=k*0.1)
        searcher_temp = INDEX_Q4.searcher(weighting=w)
        result_temp = trecEval_map_all(TOPIC_FILE, QRELS_FILE, QP_Q4, searcher_temp)

        if result_temp[1] > temp_best_gm_map[1]:
            temp_best_gm_map = result_temp
            temp_best_gm_map_d[(b,k)]=temp_best_map
            print("best gm_map: " + str(temp_best_gm_map_d[(b,k)][1])+", corresponding map: " + str(temp_best_gm_map_d[(b,k)][0]) +", b: "+str(b)+", k: "+str(k))    

        k+=1
    b+=1
    k=0
    
print("finished searching, best gm_map captured.")

# %%
# B and K1 value got from running loop above
w_final = scoring.BM25F(B=0.56, K1=2.7)
SEARCHER_Q4 = INDEX_Q4.searcher(weighting=w_final)
trecEval(TOPIC_FILE, QRELS_FILE, QP_Q4, SEARCHER_Q4)
# Out:
# num_ret               	1	469
# num_rel               	1	5
# num_rel_ret           	1	5
# map                   	1	0.0689
# Rprec                 	1	0.0000
# bpref                 	1	0.0000
# recip_rank            	1	0.0556
# iprec_at_recall_0.00  	1	0.1071
# iprec_at_recall_0.10  	1	0.1071
# iprec_at_recall_0.20  	1	0.1071
# iprec_at_recall_0.30  	1	0.1071
# iprec_at_recall_0.40  	1	0.1071
# iprec_at_recall_0.50  	1	0.1071
# iprec_at_recall_0.60  	1	0.1071
# iprec_at_recall_0.70  	1	0.0500
# iprec_at_recall_0.80  	1	0.0500
# iprec_at_recall_0.90  	1	0.0485
# iprec_at_recall_1.00  	1	0.0485
# P_5                   	1	0.0000
# P_10                  	1	0.0000
# P_15                  	1	0.0000
# P_20                  	1	0.0500
# P_30                  	1	0.1000
# P_100                 	1	0.0400
# P_200                 	1	0.0250
# P_500                 	1	0.0100
# P_1000                	1	0.0050
# num_ret               	10	490
# num_rel               	10	1
# num_rel_ret           	10	1
# map                   	10	0.3333
# Rprec                 	10	0.0000
# bpref                 	10	0.0000
# recip_rank            	10	0.3333
# iprec_at_recall_0.00  	10	0.3333
# iprec_at_recall_0.10  	10	0.3333
# iprec_at_recall_0.20  	10	0.3333
# iprec_at_recall_0.30  	10	0.3333
# iprec_at_recall_0.40  	10	0.3333
# iprec_at_recall_0.50  	10	0.3333
# iprec_at_recall_0.60  	10	0.3333
# iprec_at_recall_0.70  	10	0.3333
# iprec_at_recall_0.80  	10	0.3333
# iprec_at_recall_0.90  	10	0.3333
# iprec_at_recall_1.00  	10	0.3333
# P_5                   	10	0.2000
# P_10                  	10	0.1000
# P_15                  	10	0.0667
# P_20                  	10	0.0500
# P_30                  	10	0.0333
# P_100                 	10	0.0100
# P_200                 	10	0.0050
# P_500                 	10	0.0020
# P_1000                	10	0.0010
# num_ret               	14	315
# num_rel               	14	1
# num_rel_ret           	14	1
# map                   	14	1.0000
# Rprec                 	14	1.0000
# bpref                 	14	1.0000
# recip_rank            	14	1.0000
# iprec_at_recall_0.00  	14	1.0000
# iprec_at_recall_0.10  	14	1.0000
# iprec_at_recall_0.20  	14	1.0000
# iprec_at_recall_0.30  	14	1.0000
# iprec_at_recall_0.40  	14	1.0000
# iprec_at_recall_0.50  	14	1.0000
# iprec_at_recall_0.60  	14	1.0000
# iprec_at_recall_0.70  	14	1.0000
# iprec_at_recall_0.80  	14	1.0000
# iprec_at_recall_0.90  	14	1.0000
# iprec_at_recall_1.00  	14	1.0000
# P_5                   	14	0.2000
# P_10                  	14	0.1000
# P_15                  	14	0.0667
# P_20                  	14	0.0500
# P_30                  	14	0.0333
# P_100                 	14	0.0100
# P_200                 	14	0.0050
# P_500                 	14	0.0020
# P_1000                	14	0.0010
# num_ret               	16	1111
# num_rel               	16	7
# num_rel_ret           	16	7
# map                   	16	0.2066
# Rprec                 	16	0.1429
# bpref                 	16	0.1020
# recip_rank            	16	0.2500
# iprec_at_recall_0.00  	16	0.2727
# iprec_at_recall_0.10  	16	0.2727
# iprec_at_recall_0.20  	16	0.2727
# iprec_at_recall_0.30  	16	0.2727
# iprec_at_recall_0.40  	16	0.2727
# iprec_at_recall_0.50  	16	0.2000
# iprec_at_recall_0.60  	16	0.2000
# iprec_at_recall_0.70  	16	0.2000
# iprec_at_recall_0.80  	16	0.1400
# iprec_at_recall_0.90  	16	0.1400
# iprec_at_recall_1.00  	16	0.1400
# P_5                   	16	0.2000
# P_10                  	16	0.2000
# P_15                  	16	0.2000
# P_20                  	16	0.2000
# P_30                  	16	0.1667
# P_100                 	16	0.0700
# P_200                 	16	0.0350
# P_500                 	16	0.0140
# P_1000                	16	0.0070
# num_ret               	18	32
# num_rel               	18	1
# num_rel_ret           	18	1
# map                   	18	1.0000
# Rprec                 	18	1.0000
# bpref                 	18	1.0000
# recip_rank            	18	1.0000
# iprec_at_recall_0.00  	18	1.0000
# iprec_at_recall_0.10  	18	1.0000
# iprec_at_recall_0.20  	18	1.0000
# iprec_at_recall_0.30  	18	1.0000
# iprec_at_recall_0.40  	18	1.0000
# iprec_at_recall_0.50  	18	1.0000
# iprec_at_recall_0.60  	18	1.0000
# iprec_at_recall_0.70  	18	1.0000
# iprec_at_recall_0.80  	18	1.0000
# iprec_at_recall_0.90  	18	1.0000
# iprec_at_recall_1.00  	18	1.0000
# P_5                   	18	0.2000
# P_10                  	18	0.1000
# P_15                  	18	0.0667
# P_20                  	18	0.0500
# P_30                  	18	0.0333
# P_100                 	18	0.0100
# P_200                 	18	0.0050
# P_500                 	18	0.0020
# P_1000                	18	0.0010
# num_ret               	19	628
# num_rel               	19	2
# num_rel_ret           	19	1
# map                   	19	0.5000
# Rprec                 	19	0.5000
# bpref                 	19	0.5000
# recip_rank            	19	1.0000
# iprec_at_recall_0.00  	19	1.0000
# iprec_at_recall_0.10  	19	1.0000
# iprec_at_recall_0.20  	19	1.0000
# iprec_at_recall_0.30  	19	1.0000
# iprec_at_recall_0.40  	19	1.0000
# iprec_at_recall_0.50  	19	1.0000
# iprec_at_recall_0.60  	19	0.0000
# iprec_at_recall_0.70  	19	0.0000
# iprec_at_recall_0.80  	19	0.0000
# iprec_at_recall_0.90  	19	0.0000
# iprec_at_recall_1.00  	19	0.0000
# P_5                   	19	0.2000
# P_10                  	19	0.1000
# P_15                  	19	0.0667
# P_20                  	19	0.0500
# P_30                  	19	0.0333
# P_100                 	19	0.0100
# P_200                 	19	0.0050
# P_500                 	19	0.0020
# P_1000                	19	0.0010
# num_ret               	2	59
# num_rel               	2	2
# num_rel_ret           	2	2
# map                   	2	0.5323
# Rprec                 	2	0.5000
# bpref                 	2	0.5000
# recip_rank            	2	1.0000
# iprec_at_recall_0.00  	2	1.0000
# iprec_at_recall_0.10  	2	1.0000
# iprec_at_recall_0.20  	2	1.0000
# iprec_at_recall_0.30  	2	1.0000
# iprec_at_recall_0.40  	2	1.0000
# iprec_at_recall_0.50  	2	1.0000
# iprec_at_recall_0.60  	2	0.0645
# iprec_at_recall_0.70  	2	0.0645
# iprec_at_recall_0.80  	2	0.0645
# iprec_at_recall_0.90  	2	0.0645
# iprec_at_recall_1.00  	2	0.0645
# P_5                   	2	0.2000
# P_10                  	2	0.1000
# P_15                  	2	0.0667
# P_20                  	2	0.0500
# P_30                  	2	0.0333
# P_100                 	2	0.0200
# P_200                 	2	0.0100
# P_500                 	2	0.0040
# P_1000                	2	0.0020
# num_ret               	22	468
# num_rel               	22	1
# num_rel_ret           	22	1
# map                   	22	0.0435
# Rprec                 	22	0.0000
# bpref                 	22	0.0000
# recip_rank            	22	0.0435
# iprec_at_recall_0.00  	22	0.0435
# iprec_at_recall_0.10  	22	0.0435
# iprec_at_recall_0.20  	22	0.0435
# iprec_at_recall_0.30  	22	0.0435
# iprec_at_recall_0.40  	22	0.0435
# iprec_at_recall_0.50  	22	0.0435
# iprec_at_recall_0.60  	22	0.0435
# iprec_at_recall_0.70  	22	0.0435
# iprec_at_recall_0.80  	22	0.0435
# iprec_at_recall_0.90  	22	0.0435
# iprec_at_recall_1.00  	22	0.0435
# P_5                   	22	0.0000
# P_10                  	22	0.0000
# P_15                  	22	0.0000
# P_20                  	22	0.0000
# P_30                  	22	0.0333
# P_100                 	22	0.0100
# P_200                 	22	0.0050
# P_500                 	22	0.0020
# P_1000                	22	0.0010
# num_ret               	24	689
# num_rel               	24	1
# num_rel_ret           	24	1
# map                   	24	1.0000
# Rprec                 	24	1.0000
# bpref                 	24	1.0000
# recip_rank            	24	1.0000
# iprec_at_recall_0.00  	24	1.0000
# iprec_at_recall_0.10  	24	1.0000
# iprec_at_recall_0.20  	24	1.0000
# iprec_at_recall_0.30  	24	1.0000
# iprec_at_recall_0.40  	24	1.0000
# iprec_at_recall_0.50  	24	1.0000
# iprec_at_recall_0.60  	24	1.0000
# iprec_at_recall_0.70  	24	1.0000
# iprec_at_recall_0.80  	24	1.0000
# iprec_at_recall_0.90  	24	1.0000
# iprec_at_recall_1.00  	24	1.0000
# P_5                   	24	0.2000
# P_10                  	24	0.1000
# P_15                  	24	0.0667
# P_20                  	24	0.0500
# P_30                  	24	0.0333
# P_100                 	24	0.0100
# P_200                 	24	0.0050
# P_500                 	24	0.0020
# P_1000                	24	0.0010
# num_ret               	26	589
# num_rel               	26	3
# num_rel_ret           	26	3
# map                   	26	0.0955
# Rprec                 	26	0.0000
# bpref                 	26	0.0000
# recip_rank            	26	0.1429
# iprec_at_recall_0.00  	26	0.1429
# iprec_at_recall_0.10  	26	0.1429
# iprec_at_recall_0.20  	26	0.1429
# iprec_at_recall_0.30  	26	0.1429
# iprec_at_recall_0.40  	26	0.0811
# iprec_at_recall_0.50  	26	0.0811
# iprec_at_recall_0.60  	26	0.0811
# iprec_at_recall_0.70  	26	0.0811
# iprec_at_recall_0.80  	26	0.0811
# iprec_at_recall_0.90  	26	0.0811
# iprec_at_recall_1.00  	26	0.0811
# P_5                   	26	0.0000
# P_10                  	26	0.1000
# P_15                  	26	0.0667
# P_20                  	26	0.0500
# P_30                  	26	0.0333
# P_100                 	26	0.0300
# P_200                 	26	0.0150
# P_500                 	26	0.0060
# P_1000                	26	0.0030
# num_ret               	28	1071
# num_rel               	28	2
# num_rel_ret           	28	2
# map                   	28	0.2429
# Rprec                 	28	0.0000
# bpref                 	28	0.0000
# recip_rank            	28	0.2000
# iprec_at_recall_0.00  	28	0.2857
# iprec_at_recall_0.10  	28	0.2857
# iprec_at_recall_0.20  	28	0.2857
# iprec_at_recall_0.30  	28	0.2857
# iprec_at_recall_0.40  	28	0.2857
# iprec_at_recall_0.50  	28	0.2857
# iprec_at_recall_0.60  	28	0.2857
# iprec_at_recall_0.70  	28	0.2857
# iprec_at_recall_0.80  	28	0.2857
# iprec_at_recall_0.90  	28	0.2857
# iprec_at_recall_1.00  	28	0.2857
# P_5                   	28	0.2000
# P_10                  	28	0.2000
# P_15                  	28	0.1333
# P_20                  	28	0.1000
# P_30                  	28	0.0667
# P_100                 	28	0.0200
# P_200                 	28	0.0100
# P_500                 	28	0.0040
# P_1000                	28	0.0020
# num_ret               	4	902
# num_rel               	4	4
# num_rel_ret           	4	4
# map                   	4	0.5485
# Rprec                 	4	0.5000
# bpref                 	4	0.5000
# recip_rank            	4	1.0000
# iprec_at_recall_0.00  	4	1.0000
# iprec_at_recall_0.10  	4	1.0000
# iprec_at_recall_0.20  	4	1.0000
# iprec_at_recall_0.30  	4	1.0000
# iprec_at_recall_0.40  	4	1.0000
# iprec_at_recall_0.50  	4	1.0000
# iprec_at_recall_0.60  	4	0.1154
# iprec_at_recall_0.70  	4	0.1154
# iprec_at_recall_0.80  	4	0.0784
# iprec_at_recall_0.90  	4	0.0784
# iprec_at_recall_1.00  	4	0.0784
# P_5                   	4	0.4000
# P_10                  	4	0.2000
# P_15                  	4	0.1333
# P_20                  	4	0.1000
# P_30                  	4	0.1000
# P_100                 	4	0.0400
# P_200                 	4	0.0200
# P_500                 	4	0.0080
# P_1000                	4	0.0040
# num_ret               	6	460
# num_rel               	6	1
# num_rel_ret           	6	1
# map                   	6	0.1429
# Rprec                 	6	0.0000
# bpref                 	6	0.0000
# recip_rank            	6	0.1429
# iprec_at_recall_0.00  	6	0.1429
# iprec_at_recall_0.10  	6	0.1429
# iprec_at_recall_0.20  	6	0.1429
# iprec_at_recall_0.30  	6	0.1429
# iprec_at_recall_0.40  	6	0.1429
# iprec_at_recall_0.50  	6	0.1429
# iprec_at_recall_0.60  	6	0.1429
# iprec_at_recall_0.70  	6	0.1429
# iprec_at_recall_0.80  	6	0.1429
# iprec_at_recall_0.90  	6	0.1429
# iprec_at_recall_1.00  	6	0.1429
# P_5                   	6	0.0000
# P_10                  	6	0.1000
# P_15                  	6	0.0667
# P_20                  	6	0.0500
# P_30                  	6	0.0333
# P_100                 	6	0.0100
# P_200                 	6	0.0050
# P_500                 	6	0.0020
# P_1000                	6	0.0010
# num_ret               	7	494
# num_rel               	7	3
# num_rel_ret           	7	2
# map                   	7	0.2167
# Rprec                 	7	0.0000
# bpref                 	7	0.0000
# recip_rank            	7	0.2500
# iprec_at_recall_0.00  	7	0.4000
# iprec_at_recall_0.10  	7	0.4000
# iprec_at_recall_0.20  	7	0.4000
# iprec_at_recall_0.30  	7	0.4000
# iprec_at_recall_0.40  	7	0.4000
# iprec_at_recall_0.50  	7	0.4000
# iprec_at_recall_0.60  	7	0.4000
# iprec_at_recall_0.70  	7	0.4000
# iprec_at_recall_0.80  	7	0.0000
# iprec_at_recall_0.90  	7	0.0000
# iprec_at_recall_1.00  	7	0.0000
# P_5                   	7	0.4000
# P_10                  	7	0.2000
# P_15                  	7	0.1333
# P_20                  	7	0.1000
# P_30                  	7	0.0667
# P_100                 	7	0.0200
# P_200                 	7	0.0100
# P_500                 	7	0.0040
# P_1000                	7	0.0020
# num_ret               	9	1856
# num_rel               	9	1
# num_rel_ret           	9	1
# map                   	9	0.2500
# Rprec                 	9	0.0000
# bpref                 	9	0.0000
# recip_rank            	9	0.2500
# iprec_at_recall_0.00  	9	0.2500
# iprec_at_recall_0.10  	9	0.2500
# iprec_at_recall_0.20  	9	0.2500
# iprec_at_recall_0.30  	9	0.2500
# iprec_at_recall_0.40  	9	0.2500
# iprec_at_recall_0.50  	9	0.2500
# iprec_at_recall_0.60  	9	0.2500
# iprec_at_recall_0.70  	9	0.2500
# iprec_at_recall_0.80  	9	0.2500
# iprec_at_recall_0.90  	9	0.2500
# iprec_at_recall_1.00  	9	0.2500
# P_5                   	9	0.2000
# P_10                  	9	0.1000
# P_15                  	9	0.0667
# P_20                  	9	0.0500
# P_30                  	9	0.0333
# P_100                 	9	0.0100
# P_200                 	9	0.0050
# P_500                 	9	0.0020
# P_1000                	9	0.0010
# runid                 	all	test
# num_q                 	all	15
# num_ret               	all	9633
# num_rel               	all	35
# num_rel_ret           	all	33
# map                   	all	0.4121
# gm_map                	all	0.2811
# Rprec                 	all	0.3095
# bpref                 	all	0.3068
# recip_rank            	all	0.5112
# iprec_at_recall_0.00  	all	0.5319
# iprec_at_recall_0.10  	all	0.5319
# iprec_at_recall_0.20  	all	0.5319
# iprec_at_recall_0.30  	all	0.5319
# iprec_at_recall_0.40  	all	0.5278
# iprec_at_recall_0.50  	all	0.5229
# iprec_at_recall_0.60  	all	0.3349
# iprec_at_recall_0.70  	all	0.3311
# iprec_at_recall_0.80  	all	0.2980
# iprec_at_recall_0.90  	all	0.2979
# iprec_at_recall_1.00  	all	0.2979
# P_5                   	all	0.1733
# P_10                  	all	0.1133
# P_15                  	all	0.0800
# P_20                  	all	0.0667
# P_30                  	all	0.0556
# P_100                 	all	0.0213
# P_200                 	all	0.0110
# P_500                 	all	0.0044
# P_1000                	all	0.0022

# %%
sampleQuery = QP_Q4.parse("Emergency and disaster preparedness assistance") # parse topic 16
sampleQueryResults = SEARCHER_Q4.search(sampleQuery, limit=None)
# inspect the result:
# for each document print the rank and the score
for (docnum, result) in enumerate(sampleQueryResults):
    score = sampleQueryResults.score(docnum)
    fileName = os.path.basename(result["file_path"])
    print(fileName, docnum, score)
# Out:
# G00-34-3591274 0 26.030995129301573
# G00-68-3661801 1 25.066902612605578
# G00-70-2681284 2 24.282161587672004
# G00-21-2114990 3 23.457763430628543
# G00-84-2647789 4 23.292300749759384
# G00-77-1693859 5 23.24168281117828
# G00-03-2245885 6 23.195509312631383
# G00-21-0494028 7 22.64257000655455
# G00-05-0719078 8 22.492704440707005
# G00-53-0263242 9 21.88061758429768
# G00-86-3719816 10 21.731413202170955
# G00-60-2564326 11 21.624171648367508
# G00-45-0006211 12 21.612991633253735
# G00-88-2853984 13 21.612991633253735
# G00-18-2154531 1063 1.3787619506264774
# G00-32-3296216 1064 1.3787619506264774
# G00-20-3716305 1065 1.3733904855787467
# G00-65-0346398 1066 1.3341041902002786
# G00-05-3391805 1067 1.3234181561807146
# G00-83-3277638 1068 1.3213851807220995
# G00-59-1311489 1069 1.3178141466899174
# G00-86-2059462 1070 1.29994814442033
# G00-55-0000000 1071 1.2737375042813306
# G00-52-3079304 1072 1.2543991582756102
# G00-50-1075346 1073 1.2521499313914595
# G00-15-3695921 1074 1.238271422663273
# G00-86-1693753 1075 1.234046880347998
# G00-31-1130222 1076 1.2120874487113675
# G00-37-2777794 1077 1.2120874487113675
# G00-55-1952930 1078 1.2093341533821478
# G00-29-2968932 1079 1.2053188954867515
# G00-96-1395116 1080 1.2053188954867515
# G00-38-2705227 1081 1.1869878949671646
# G00-42-2097415 1082 1.1869878949671646
# G00-39-3477058 1083 1.1111896191088924
# G00-26-4176011 1084 1.086412558511376
# G00-45-4032177 1085 1.0621371759512537
# G00-70-3118212 1086 1.037816454348575
# G00-93-1783036 1087 1.037816454348575
# G00-57-3600665 1088 0.9977754879468266
# G00-94-0708359 1089 0.9958292307745881
# G00-42-1455285 1090 0.972975450875285
# G00-98-1047338 1091 0.967732044389299
# G00-80-2865414 1092 0.9228256985446834
# G00-70-3168895 1093 0.9167609333173578
# G00-73-3314008 1094 0.8996194087662084
# G00-47-2967546 1095 0.8912455551571872
# G00-63-2233776 1096 0.8476575797539079
# G00-25-3027752 1097 0.796158206347633
# G00-73-2660773 1098 0.7761821203645589
# G00-39-4066050 1099 0.7376947312546859
# G00-92-0142623 1100 0.7189183379850742
# G00-76-2323292 1101 0.6660072895476955
# G00-79-2569923 1102 0.6601025698349109
# G00-43-3607125 1103 0.6333109291157438
# G00-91-3181951 1104 0.6282381752909645
# G00-26-1962814 1105 0.6136577944489902
# G00-73-3170442 1106 0.5812627307686327
# G00-25-1928405 1107 0.5689598656697128
# G00-33-0053624 1108 0.44915018584362154
# G00-43-1143881 1109 0.4401445154016156
# G00-60-0631416 1110 0.35436355279458404

# %% [markdown]
# ### Q4 (c): Provide answer to Q4 (a) here [markdown cell]
# **Modification**
#
# - When creating the searcher, tunning the BM25F scoring algorithm by changing the value of B and K1 to yield the best map & gm_map score. Optimal B and K1 has been decided to be 0.56 and 2.7 respectively (using loop for adjusting and tunning).
#   * set range for B (0-1) increment 0.01/iteration - **0.56 B reflected a less normalizd field-length than default (0.75)**
#   * set range for K1 (0-10) increment 0.1/iteration - **2.7 K1 reflected a slower term-frequency saturation than default (1.2)**
#
# Topic | Measure | Value_in_Q2 | Value_in_Q3 | Value_in_Q4 | Improvement(Q3->Q4)
# --- | --- | --- | --- | --- | ---
# 1 | map | 0 | 0.0673 | 0.0689 | 2.37%
# 10 | map | 0.1667 | 0.2500 | 0.3333 | 33.32%
# 14 | map | 0.2500 | 1 | 1 | 0%
# ***16*** | ***map*** | ***0*** | ***0.1552*** | ***0.2066*** | ***33.12%***
# 18 | map | 1 | 1 | 1 | 0%
# 19 | map | N/A | 0.5000 | 0.5000 | 0%
# 2 | map | 0 | 0.5385| 0.5323 | -1.15%
# 22 | map | 0.2000 | 0.0357| 0.0435 | 21.85%
# 24 | map | 1 | 1 | 1 | 0%
# 26 | map | 0.1111 | 0.1074| 0.0955 | -11.08%
# 28 | map | 0 | 0.2262 | 0.2429 | 7.38%
# 4 | map | 0.0312 | 0.5614| 0.5485 | -2.30%
# 6 | map | 0 | 0.1667 | 0.1429 | -14.28%
# 7 | map | 0 | 0.1778 | 0.2167 | 21.88%
# 9 | map | 0 | 0.0588 | 0.2500 | 325.17%
# **all** | **map** | **0.1971** | **0.3897** | **0.4121** | **5.75%**
# **all** | **gm_map** | **0.0015** | **0.2427** | **0.2811** | **15.82%**
#
# <br><br>
# **Confusion Matrix (topic #16): topic#16's map increased by 33.12% from Q3**
#
# Confusion Matrix | Relevant | Non-Relevant
# --- | --- | ---
# *Retrieved* | 7 | 1104
# *Not Retrieved* | 0 | 2967
#
# **False Positive:**
# <br>There are still **1111** retrieved documents in total but **1104** of them are not relevant, precision dropped largely.
# - **IMPROVEMENT** - first True Positive document ***G00-21-2114990*** now ranked **4th (recip_rank = 0.25)** in the total retrieved document (formally 12th in Q3).
#
# **False Negative:**
# <br>All False Negative document eliminated.<br>

# %% [markdown]
# ### Q4 (d): Provide answer to Q4 (a) here [markdown cell]
# YES, refer to table in 4c)

# %% [markdown]
# ### Q4 (e): Provide answer to Q4 (a) here [markdown cell]
# YES, refer to table in 4c)

# %% [markdown]
# ### Q4 (f): Provide answer to Q4 (a) here [markdown cell]
# It is a good idea.
# - map score for overall and topic #16 increased from Q3 (of course also from Q2)
# - gm_map score also increased from Q3 and Q2
# - Although # of retrieved documents and # of retrieved relevant documents did not increase from Q3, the ranks of relevant documents are now higher than Q3 and Q2 (since higher map and gm_map, and recip_rank is higher as well).

# %% [markdown]
# ## Validation

# %%
# Run the following cells to make sure your code returns the correct value types

# %%
from whoosh.index import FileIndex
from whoosh.qparser import QueryParser
from whoosh.searching import Searcher
import os.path

# %% [markdown]
# ### Q2 Validation

# %%
assert(isinstance(INDEX_Q2, FileIndex)), "Index Type"
assert(isinstance(QP_Q2, QueryParser)), "Query Parser Type"
assert(isinstance(SEARCHER_Q2, Searcher)), "Searcher Type"
print("Q2 Types Validated")
# Out:
# Q2 Types Validated

# %% [markdown]
# ### Q3 Validation

# %%
assert(isinstance(INDEX_Q3, FileIndex)), "Index Type"
assert(isinstance(QP_Q3, QueryParser)), "Query Parser Type"
assert(isinstance(SEARCHER_Q3, Searcher)), "Searcher Type"
print("Q3 Types Validated")
# Out:
# Q3 Types Validated

# %% [markdown]
# ### Q4 Validation (Graduate Students)

# %%
assert((not GRAD_STUDENT) or isinstance(INDEX_Q4, FileIndex)), "Index Type"
assert((not GRAD_STUDENT) or isinstance(QP_Q4, QueryParser)), "Query Parser Type"
assert((not GRAD_STUDENT) or isinstance(SEARCHER_Q4, Searcher)), "Searcher Type"
print("Q4 Types Validated")
# Out:
# Q4 Types Validated
